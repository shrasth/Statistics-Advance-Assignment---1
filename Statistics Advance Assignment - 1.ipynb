# %% [markdown]
# ## Q1. What is the Probability density function?

# %% [markdown]
# It describes the likelihood of a continuous random variable taking on a particular value or falling within a certain range of values.

# %% [markdown]
# ## Q2. What are the types of Probability distribution?

# %% [markdown]
# There are three types of probability distribution:
#
# 1. Normal/Gaussian distribution
#
# 2. Bernoulli distribution
#
# 3. Uniform distribution
#
# 4. Log normal distribution
#
# 5. Poisson distribution
#
# 6. Power law distribution
#
# 7. Binomial distribution

# %% [markdown]
# ## Q3. Write a Python function to calculate the probability density function of a normal distribution with given mean and standard deviation at a given point.

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(1,50,200)
def normal_dist(x , mean , sd):
    prob_density = (1 / (sd * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean) / sd)**2)
    return prob_density
mean = np.mean(x)
sd = np.std(x)
pdf = normal_dist(x,mean,sd)
plt.plot(x,pdf , color = 'red')
plt.xlabel('Data points')
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %% [markdown]
# ## Q4. What are the properties of Binomial distribution? Give two examples of events where binomial distribution can be applied.

# %% [markdown]
# The properties of binomial distribution are as follows:
#
# 1. The Binomial distribution is a discrete probability distribution, meaning it is defined for a specific set of non-negative integer values.
#
# 2. The distribution represents a fixed number of independent trials, denoted by "n," where each trial can result in a success or failure.
#
# 3. Each trial must be independent of the others, meaning the outcome of one trial does not affect the outcome of the others.
#
#
# Examples of events where binomial distribution can be applied:
#
# 1. Tossing a coin
#
# 2. Product defects

# %% [markdown]
# ## Q5. Generate a random sample of size 1000 from a binomial distribution with probability of success 0.4 and plot a histogram of the results using matplotlib.

# %%
import numpy as np
from scipy.stats import binom
import matplotlib.pyplot as plt
n = 1000
p = 0.4
x_values = np.arange(0,n+1)
prob = binom.pmf(x_values,n,p)

plt.bar(x_values,prob)
plt.show()

# %% [markdown]
# ## Q6. Write a Python function to calculate the cumulative distribution function of a Poisson distribution with given mean at a given point.

# %%
from scipy.stats import poisson

def poisson_cdf(mean, point):
    return poisson.cdf(point, mean)

mean = 3
point = 5

cdf_at_point = poisson_cdf(mean, point)
print(f"CDF at point {point} with mean {mean}: {cdf_at_point:.6f}")
# Out:
# CDF at point 5 with mean 3: 0.916082

# %% [markdown]
# For range of occurrences

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

k = np.arange(0,19)
cdf = np.round(poisson.cdf(k,mu=5),3)

for val, prob in zip(k,cdf):
    print(f"The value {val} has prob {prob}")
# Out:
# The value 0 has prob 0.007
# The value 1 has prob 0.04
# The value 2 has prob 0.125
# The value 3 has prob 0.265
# The value 4 has prob 0.44
# The value 5 has prob 0.616
# The value 6 has prob 0.762
# The value 7 has prob 0.867
# The value 8 has prob 0.932
# The value 9 has prob 0.968
# The value 10 has prob 0.986
# The value 11 has prob 0.995
# The value 12 has prob 0.998
# The value 13 has prob 0.999
# The value 14 has prob 1.0
# The value 15 has prob 1.0
# The value 16 has prob 1.0
# The value 17 has prob 1.0
# The value 18 has prob 1.0

# %% [markdown]
# ## Q7. How Binomial distribution different from Poisson distribution?

# %% [markdown]
# The key differences between the two distributions are:
#
# 1. **Nature of the events**: In the Binomial distribution, the events are discrete and have a binary outcome (success or failure), whereas in the Poisson distribution, the events are rare occurrences that can be considered continuous.
#
# 2. **Number of trials/samples**: The Binomial distribution models the number of successes in a fixed number of trials or samples, whereas the Poisson distribution models the number of rare events that occur in a fixed interval or sample size.
#
# 3. **Probability of success/rate of occurrence**: In the Binomial distribution, the probability of success is constant across trials or samples, whereas in the Poisson distribution, the rate of occurrence is constant over time or space.
#
# 4. **Assumptions**: The Binomial distribution assumes that the trials are independent and identically distributed, whereas the Poisson distribution assumes that the rare events occur independently of each other and that the rate of occurrence is constant over time or space.

# %% [markdown]
# ## Q8. Generate a random sample of size 1000 from a Poisson distribution with mean 5 and calculate the sample mean and variance.

# %%
from scipy.stats import poisson
import numpy as np

mean =5
sample_size = 1000

#Generating the sample
sample = np.random.poisson(mean,sample_size)

#Calculating the sample mean
sample_mean = np.mean(sample)

#Calculating the variance

sample_variance = np.var(sample,ddof=1)

print(f"Sample mean {sample_mean} and Variance {sample_variance}")
# Out:
# Sample mean 5.001 and Variance 4.723722722722722

# %% [markdown]
# ## Q9. How mean and variance are related in Binomial distribution and Poisson distribution?

# %% [markdown]
# In a **binomial distribution**, the mean (or expected value) and variance are related by the following formula:
#
#     mean = np variance = np(1-p)
#
# where n is the number of trials and p is the probability of success in each trial.
#
# In a **Poisson distribution**, the mean and variance are equal and are given by:
#
#     mean = variance = λ
#
# where λ is the rate parameter of the Poisson distribution.
#
# The relationship between mean and variance in these distributions reflects the nature of the underlying processes they model.
#
# In a **binomial distribution**, the variance increases as the probability of success (p) moves away from 0.5, indicating that the spread of the distribution increases as the probability of success becomes more extreme.
#
# In a **Poisson distribution**, the variance is equal to the mean because the distribution models events that occur randomly and independently with a constant rate, such as the number of arrivals in a fixed period of time. The constant rate λ determines both the mean and the variance, and the distribution has no underlying variability beyond what is explained by the rate parameter.

# %% [markdown]
# ## Q10. In normal distribution with respect to mean position, where does the least frequent data appear?

# %% [markdown]
# In a normal distribution, the least frequent data points are located in the tails of the distribution, which are the regions farthest away from the mean. The probability of observing a data point in the tails decreases rapidly as the distance from the mean increases.
